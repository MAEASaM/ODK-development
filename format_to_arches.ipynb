# %% [markdown]
# ## Importing all the packages

# %%
import pandas as pd
import numpy as np

# %%
from dictionary import col_name
from my_func import mutliple_choice

# %% [markdown]
# ## Some display settings

# %%
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', -1)  # or 199
pd.set_option('display.max_rows', None)
# Out:
# C:\Users\zolok\miniconda3\envs\analysis\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ## Reading and cleaning data

# %%
df_form = pd.read_excel('MAESAM Form.xlsx', sheet_name = 1) #This is the form.

# %%
main = mutliple_choice (pd.read_excel('export_data_2.xlsx', sheet_name = 0), ['site_summary/site_cultural_periods'])
# main = mutliple_choice(df, ['site_summary/site_cultural_periods'])
main
# Out:
# C:\Users\zolok\miniconda3\envs\analysis\lib\site-packages\pandas\core\frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# C:\Users\zolok\OneDrive\Documents\ODK\my_func.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_melted_new[name] = df_melted_new[name].str.replace(n + '/','')
#                     start                     end  today  _INTRODUCTION  \
# 0 2022-05-09 09:40:53.720 2022-05-09 09:50:53.387  44690 NaN
# 1 2022-05-09 09:40:53.720 2022-05-09 09:50:53.387  44690 NaN
# ...

# %%
descriptive_type_repeat = pd.read_excel('export_data_2.xlsx', sheet_name = 1) # no multiple choice columns; parent table: main
descriptive_type_repeat
# Out:
#   descriptive_type_repeat/descriptive_type_group/descriptive_type  \
# 0  administrative_(1)
# 1  anthill_burial
#
#   descriptive_type_repeat/descriptive_type_group/descriptive_type_certainty  \
# 0  low
# 1  low
#
#    _id  _uuid  _submission_time  _index      _parent_table_name  \
# 0 NaN  NaN    NaN                1       anyCuBvPsDaVQx9dX34kKx
# 1 NaN  NaN    NaN                2       anyCuBvPsDaVQx9dX34kKx
#
#    _parent_index  _tags  _notes
# 0  1             NaN    NaN
# 1  2             NaN    NaN

# %%
functions_repeat = pd.read_excel('export_data_2.xlsx', sheet_name = 2) # no multiple choice columns; parent table: main
functions_repeat
# Out:
#   functions_repeat/function_group/function  \
# 0  isolated_find_
# 1  battlefield
# 2  administrative_(1)
# 3  agriculture_and_subsistence
# 4  alluvial_deposit
#
#   functions_repeat/function_group/function_certainty  _id  _uuid  \
# 0  medium                                            NaN  NaN
# 1  low                                               NaN  NaN
# 2  low                                               NaN  NaN
# 3  low                                               NaN  NaN
# 4  high                                              NaN  NaN
#
#    _submission_time  _index      _parent_table_name  _parent_index  _tags  \
# 0 NaN                1       anyCuBvPsDaVQx9dX34kKx  1             NaN
# 1 NaN                2       anyCuBvPsDaVQx9dX34kKx  1             NaN
# 2 NaN                3       anyCuBvPsDaVQx9dX34kKx  1             NaN
# 3 NaN                4       anyCuBvPsDaVQx9dX34kKx  1             NaN
# ...

# %%
landowner_repeat_group = pd.read_excel('export_data_2.xlsx', sheet_name = 3) # no multiple choice columns; parent table: main
landowner_repeat_group
# Out:
#   landowner_repeat_group/landowner_group/landowner_name  \
# 0  Kiala
# 1  Zime
# 2  Kiala
# 3  Kiala
#
#    landowner_repeat_group/landowner_group/landowner_contact  _id  _uuid  \
# 0  17896996                                                 NaN  NaN
# 1  2500936                                                  NaN  NaN
# 2  1288669                                                  NaN  NaN
# 3  188669                                                   NaN  NaN
#
#    _submission_time  _index      _parent_table_name  _parent_index  _tags  \
# 0 NaN                1       anyCuBvPsDaVQx9dX34kKx  1             NaN
# 1 NaN                2       anyCuBvPsDaVQx9dX34kKx  1             NaN
# 2 NaN                3       anyCuBvPsDaVQx9dX34kKx  2             NaN
# 3 NaN                4       anyCuBvPsDaVQx9dX34kKx  2             NaN
#
#    _notes
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN

# %%
natural_feature_photos_repeat = pd.read_excel('export_data_2.xlsx', sheet_name = 4) # no multiple choice columns; parent table: main
natural_feature_photos_repeat
# Out:
# Empty DataFrame
# Columns: [natural_feature_photos_repeat/natural_feature_photo, _id, _uuid, _submission_time, _index, _parent_table_name, _parent_index, _tags, _notes]
# Index: []

# %%
site_name_repeat = pd.read_excel('export_data_2.xlsx', sheet_name = 5)  # no multiple choice columns; parent table: main
site_name_repeat
# Out:
#   site_name_repeat/name_site_group/name_value  \
# 0  Serge
# 1  Kiala
# 2  Kiala
# 3  Kiala
#
#   site_name_repeat/name_site_group/name_type  _id  _uuid  _submission_time  \
# 0  official                                  NaN  NaN    NaN
# 1  primaire                                  NaN  NaN    NaN
# 2  official                                  NaN  NaN    NaN
# 3  primaire                                  NaN  NaN    NaN
#
#    _index      _parent_table_name  _parent_index  _tags  _notes
# 0  1       anyCuBvPsDaVQx9dX34kKx  1             NaN    NaN
# 1  2       anyCuBvPsDaVQx9dX34kKx  1             NaN    NaN
# 2  3       anyCuBvPsDaVQx9dX34kKx  1             NaN    NaN
# 3  4       anyCuBvPsDaVQx9dX34kKx  2             NaN    NaN

# %%
site_photo_repeat = pd.read_excel('export_data_2.xlsx', sheet_name = 6) # no multiple choice columns; parent table: main
site_photo_repeat
# Out:
#   site_photos_repeat/site_photo  _id  _uuid  _submission_time  _index  \
# 0  1652082286398.jpg            NaN  NaN    NaN                1
# 1  1652082296300.jpg            NaN  NaN    NaN                2
# 2  1652083545222.jpg            NaN  NaN    NaN                3
# 3  1652083556249.jpg            NaN  NaN    NaN                4
#
#        _parent_table_name  _parent_index  _tags  _notes
# 0  anyCuBvPsDaVQx9dX34kKx  1             NaN    NaN
# 1  anyCuBvPsDaVQx9dX34kKx  1             NaN    NaN
# 2  anyCuBvPsDaVQx9dX34kKx  2             NaN    NaN
# 3  anyCuBvPsDaVQx9dX34kKx  2             NaN    NaN

# %%
site_sketch_map_repeat = pd.read_excel('export_data_2.xlsx', sheet_name = 7) # no multiple choice columns; parent table: main
site_name_repeat
# Out:
#   site_name_repeat/name_site_group/name_value  \
# 0  Serge
# 1  Kiala
# 2  Kiala
# 3  Kiala
#
#   site_name_repeat/name_site_group/name_type  _id  _uuid  _submission_time  \
# 0  official                                  NaN  NaN    NaN
# 1  primaire                                  NaN  NaN    NaN
# 2  official                                  NaN  NaN    NaN
# 3  primaire                                  NaN  NaN    NaN
#
#    _index      _parent_table_name  _parent_index  _tags  _notes
# 0  1       anyCuBvPsDaVQx9dX34kKx  1             NaN    NaN
# 1  2       anyCuBvPsDaVQx9dX34kKx  1             NaN    NaN
# 2  3       anyCuBvPsDaVQx9dX34kKx  1             NaN    NaN
# 3  4       anyCuBvPsDaVQx9dX34kKx  2             NaN    NaN

# %%
threat_type_repeat = pd.read_excel('export_data_2.xlsx', sheet_name = 8) # no multiple choice columns; parent table: main
threat_type_repeat
# Out:
#   threat_type_repeat/potential_threats/threat_type  \
# 0  biodeterioration
# 1  bushfire
# 2  antbears
# 3  displacement_of_people
#
#   threat_type_repeat/potential_threats/threat_severity  _id  _uuid  \
# 0  medium                                              NaN  NaN
# 1  medium                                              NaN  NaN
# 2  high                                                NaN  NaN
# 3  medium                                              NaN  NaN
#
#    _submission_time  _index      _parent_table_name  _parent_index  _tags  \
# 0 NaN                1       anyCuBvPsDaVQx9dX34kKx  1             NaN
# 1 NaN                2       anyCuBvPsDaVQx9dX34kKx  1             NaN
# 2 NaN                3       anyCuBvPsDaVQx9dX34kKx  1             NaN
# 3 NaN                4       anyCuBvPsDaVQx9dX34kKx  2             NaN
#
#    _notes
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN

# %%
threat_type_repeat_potential_th = pd.read_excel('export_data_2.xlsx', sheet_name = 9) #no multiple choice columns; parent table: threat_type_repeat
threat_type_repeat_potential_th
# Out:
#   threat_type_repeat/potential_threats/threats_photo/condition_photo  _id  \
# 0  1652082492599.jpg                                                 NaN
# 1  1652082510893.jpg                                                 NaN
# 2  1652082565128.jpg                                                 NaN
# 3  1652082594813.jpg                                                 NaN
# 4  1652082604769.jpg                                                 NaN
# 5  1652082613988.jpg                                                 NaN
# 6  1652083620148.jpg                                                 NaN
# 7  1652083632761.jpg                                                 NaN
#
#    _uuid  _submission_time  _index  _parent_table_name  _parent_index  _tags  \
# 0 NaN    NaN                1       threat_type_repeat  1             NaN
# 1 NaN    NaN                2       threat_type_repeat  1             NaN
# 2 NaN    NaN                3       threat_type_repeat  2             NaN
# ...

# %%
transects = pd.read_excel('export_data_2.xlsx', sheet_name = 10) # #no multiple choice columns; parent table: main
transects
# Out:
#   transects/transect_direction  \
# 0  NS
# 1  EW
#
#    transects/transect_direction_info/transect_direction_other  \
# 0 NaN
# 1 NaN
#
#    transects/transect_direction_info/transect_id  \
# 0  1
# 1  1
#
#    transects/transects_group/repeat_count  \
# 0  2
# 1  1
#
#    transects/transects_group/unit_count  _id  _uuid  _submission_time  _index  \
# 0  2                                    NaN  NaN    NaN                1
# 1  1                                    NaN  NaN    NaN                2
#
#        _parent_table_name  _parent_index  _tags  _notes
# 0  anyCuBvPsDaVQx9dX34kKx  2             NaN    NaN
# 1  anyCuBvPsDaVQx9dX34kKx  2             NaN    NaN

# %%
transects_summary_transect_phot = pd.read_excel('export_data_2.xlsx', sheet_name = 11)
transects_summary_transect_phot# #no multiple choice columns; parent table: main
# Out:
#   transects_summary/transect_photos_repeat/transect_photo  _id  _uuid  \
# 0  1652082725038.jpg                                      NaN  NaN
# 1  1652082737078.jpg                                      NaN  NaN
#
#    _submission_time  _index      _parent_table_name  _parent_index  _tags  \
# 0 NaN                1       anyCuBvPsDaVQx9dX34kKx  2             NaN
# 1 NaN                2       anyCuBvPsDaVQx9dX34kKx  2             NaN
#
#    _notes
# 0 NaN
# 1 NaN

# %%
transects_transects_group_unit = mutliple_choice(pd.read_excel('export_data_2.xlsx', sheet_name = 12), ['transects/transects_group/unit/unit_cultural_periods',
'transects/transects_group/unit/surface_material_type','transects/transects_group/unit/associated_materials_features']) #no multiple choice columns; parent table: transects
transects_transects_group_unit.head(10)
# Out:
# C:\Users\zolok\miniconda3\envs\analysis\lib\site-packages\pandas\core\frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# C:\Users\zolok\OneDrive\Documents\ODK\my_func.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_melted_new[name] = df_melted_new[name].str.replace(n + '/','')
#    transects/transects_group/unit/unit_help  \
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
# 5 NaN
# 6 NaN
# 7 NaN
#
#    transects/transects_group/unit/units_count  \
# 0  1
# 1  1
# 2  1
# 3  1
# 4  1
# 5  1
# 6  2
# 7  1
#
# ...

# %%
transects_transects_group_unit_ = pd.read_excel('export_data_2.xlsx', sheet_name = 13) #no multiple choice columns; parent table: transects_transects_group_unit_
transects_transects_group_unit_
# Out:
#   transects/transects_group/unit/unit_photo_repeat/unit_photo  _id  _uuid  \
# 0  1652082859565.jpg                                          NaN  NaN
# 1  1652082878321.jpg                                          NaN  NaN
# 2  1652083131687.jpg                                          NaN  NaN
# 3  1652083140962.jpg                                          NaN  NaN
# 4  1652083283260.jpg                                          NaN  NaN
# 5  1652083295971.jpg                                          NaN  NaN
#
#    _submission_time  _index              _parent_table_name  _parent_index  \
# 0 NaN                1       transects_transects_group_unit  1
# 1 NaN                2       transects_transects_group_unit  1
# 2 NaN                3       transects_transects_group_unit  2
# 3 NaN                4       transects_transects_group_unit  2
# 4 NaN                5       transects_transects_group_unit  3
# 5 NaN                6       transects_transects_group_unit  3
#
# ...

# %%
transects_transects_group_unit1 = pd.read_excel('export_data_2.xlsx', sheet_name = 14) #no multiple choice columns; parent table: transects_transects_group_unit
transects_transects_group_unit1
# Out:
# Empty DataFrame
# Columns: [transects/transects_group/unit/sf_group2/sa_photo_repeat/sa_photo, _id, _uuid, _submission_time, _index, _parent_table_name, _parent_index, _tags, _notes]
# Index: []

# %% [markdown]
# ## Merging section

# %% [markdown]
# Merging parent tables to grand-children tables

# %%
##joining transects_transects_group_unit_ and  transects_transects_group_unit1 (children) to transects (parent)
transects_unit = transects_transects_group_unit.merge(transects_transects_group_unit_, how= 'left', left_on=['_index'], right_on = ['_parent_index']) \
        .rename(columns={'_index_x':'_index', '_parent_index_x':'_parent_index'}) \
        .merge(transects_transects_group_unit1, how= 'left', left_on=['_index'], right_on = ['_parent_index']) \
        .rename(columns={'_index_x':'_index', '_parent_index_x':'_parent_index'}) #Lways renaming index and parent index of parent table
transects_unit.head(2)
# Out:
#    transects/transects_group/unit/unit_help  \
# 0 NaN
# 1 NaN
#
#    transects/transects_group/unit/units_count  \
# 0  1
# 1  1
#
#   transects/transects_group/unit/unit_type  \
# 0  unit_on_transect
# 1  unit_on_transect
#
#                    transects/transects_group/unit/unit_location  \
# 0  -26.1726202 27.9928721 1702.9000244140625 20.808000564575195
# 1  -26.1726202 27.9928721 1702.9000244140625 20.808000564575195
#
#    transects/transects_group/unit/_unit_location_latitude  \
# 0 -26.17262
# 1 -26.17262
#
#    transects/transects_group/unit/_unit_location_longitude  \
# 0  27.992872
# 1  27.992872
#
#    transects/transects_group/unit/_unit_location_altitude  \
# 0  1702.900024
# 1  1702.900024
#
#    transects/transects_group/unit/_unit_location_precision  \
# 0  20.808001
# 1  20.808001
#
#    transects/transects_group/unit/gps_accuracy  \
# 0 NaN
# 1 NaN
#
#    transects/transects_group/unit/coor_latitude  \
# 0 NaN
# 1 NaN
#
# ...

# %%
##joining transects_unit (children) to transects (parent)
transect_merge = transects.merge(transects_unit, how= 'left', left_on=['_index'], right_on = ['_parent_index']) \
        .rename(columns={'_index_x':'_index', '_parent_index_x':'_parent_index'}) 
# transect_merge.head(20)
# Out:
# C:\Users\zolok\miniconda3\envs\analysis\lib\site-packages\pandas\core\frame.py:9203: FutureWarning: Passing 'suffixes' which cause duplicate columns {'_parent_table_name_y', '_parent_index_y', '_uuid_y', '_id_y', '_tags_y', '_submission_time_y', '_notes_y', '_index_y'} in the result is deprecated and will raise a MergeError in a future version.
#   validate=validate,

# %%
##joining  threat_type_repeat_potential_th (child) to threat_type_repeat (parent)
threat_merge = threat_type_repeat.merge(threat_type_repeat_potential_th, how= 'left', left_on=['_index'], right_on = ['_parent_index']) \
        .rename(columns={'_index_x':'_index', '_parent_index_x':'_parent_index'}) 
threat_merge.head(2)
# Out:
#   threat_type_repeat/potential_threats/threat_type  \
# 0  biodeterioration
# 1  biodeterioration
#
#   threat_type_repeat/potential_threats/threat_severity  _id_x  _uuid_x  \
# 0  medium                                              NaN    NaN
# 1  medium                                              NaN    NaN
#
#    _submission_time_x  _index    _parent_table_name_x  _parent_index  _tags_x  \
# 0 NaN                  1       anyCuBvPsDaVQx9dX34kKx  1             NaN
# 1 NaN                  1       anyCuBvPsDaVQx9dX34kKx  1             NaN
#
#    _notes_x  \
# 0 NaN
# 1 NaN
#
#   threat_type_repeat/potential_threats/threats_photo/condition_photo  _id_y  \
# 0  1652082492599.jpg                                                 NaN
# 1  1652082510893.jpg                                                 NaN
#
#    _uuid_y  _submission_time_y  _index_y _parent_table_name_y  \
# 0 NaN      NaN                  1         threat_type_repeat
# ...

# %% [markdown]
# ### Merging child tables to main parent (main)

# %%
main_merge = main.merge(descriptive_type_repeat, how= 'left', left_on=['_index'], right_on = ['_parent_index']) \
        .rename(columns={'_index_x':'_index', '_parent_index_x':'_parent_index'}) \
        .merge(functions_repeat, how= 'left', left_on=['_index'], right_on = ['_parent_index']) \
        .rename(columns={'_index_x':'_index', '_parent_index_x':'_parent_index'}) \
        .merge(landowner_repeat_group, how= 'left', left_on=['_index'], right_on = ['_parent_index']) \
        .rename(columns={'_index_x':'_index', '_parent_index_x':'_parent_index'}) \
        .merge(natural_feature_photos_repeat, how= 'left', left_on=['_index'], right_on = ['_parent_index']) \
        .rename(columns={'_index_x':'_index', '_parent_index_x':'_parent_index'}) \
        .merge(site_name_repeat, how= 'left', left_on=['_index'], right_on = ['_parent_index']) \
        .rename(columns={'_index_x':'_index', '_parent_index_x':'_parent_index'}) \
        .merge(site_sketch_map_repeat, how= 'left', left_on=['_index'], right_on = ['_parent_index']) \
        .rename(columns={'_index_x':'_index', '_parent_index_x':'_parent_index'}) \
        .merge(threat_merge, how= 'left', left_on=['_index'], right_on = ['_parent_index']) \
         .rename(columns={'_index_x':'_index', '_parent_index_x':'_parent_index'}) \
        .merge(transect_merge, how= 'left', left_on=['_index'], right_on = ['_parent_index']) \
        .rename(columns={'_index_x':'_index', '_parent_index_x':'_parent_index'}) \
        .merge(transects_summary_transect_phot, how= 'left', left_on=['_index'], right_on = ['_parent_index']) \
        .rename(columns={'_index_x':'_index', '_parent_index_x':'_parent_index'}) \
# Out:
# C:\Users\zolok\miniconda3\envs\analysis\lib\site-packages\pandas\core\frame.py:9203: FutureWarning: Passing 'suffixes' which cause duplicate columns {'_id_x', '_uuid_x', '_submission_time_x', '_notes_x', '_parent_table_name_x', '_tags_x'} in the result is deprecated and will raise a MergeError in a future version.
#   validate=validate,
# C:\Users\zolok\miniconda3\envs\analysis\lib\site-packages\pandas\core\frame.py:9203: FutureWarning: Passing 'suffixes' which cause duplicate columns {'_index_y_x', '_parent_index_y_x'} in the result is deprecated and will raise a MergeError in a future version.
#   validate=validate,

# %%
main_merge.tail(2)
# Out:
#                       start                     end  today  _INTRODUCTION  \
# 702 2022-05-09 09:51:34.507 2022-05-09 10:07:44.533  44690 NaN
# 703 2022-05-09 09:51:34.507 2022-05-09 10:07:44.533  44690 NaN
#
#     recorder_info/institution_name recorder_info/recorder_name  \
# 702  national_museums_of_kenya      ken1
# 703  national_museums_of_kenya      ken1
#
#      recorder_info/other_recorder recorder_info/Recorder_role_type  \
# 702 NaN                            Technician
# 703 NaN                            Technician
#
#      existing_reference                         site_source  \
# 702 NaN                  newly_recorded_site/built_heritage
# 703 NaN                  newly_recorded_site/built_heritage
#
#     associated_id_name_group/associated_id_name  \
# 702  Sdff
# 703  Sdff
#
#     associated_id_name_group/associated_id_value  pre_site_id  pre_grid_id  \
# 702  Ssf1233                                     NaN          NaN
# ...

# %% [markdown]
# ## Selecting columns that will go to Arches from the main merge table

# %%
col_name_new = list(col_name.values()) #Getting all the values of our main dictionary
col_name_new = np.array(col_name_new) #Converting them in an array
# col_name_new = (col_name_new, end="")
# type(col_name_new)

# %%
main_merge.rename(columns=col_name, inplace=True)

# %%
main_merge_new = main_merge[col_name_new]
main_merge_new.tail(5)
# Out:
#     associated id name associated id value  \
# 699  Sdff               Ssf1233
# 700  Sdff               Ssf1233
# 701  Sdff               Ssf1233
# 702  Sdff               Ssf1233
# 703  Sdff               Ssf1233
#
#                             site source  site latitude  site longitude  \
# 699  newly_recorded_site/built_heritage -26.172528      27.992787
# 700  newly_recorded_site/built_heritage -26.172528      27.992787
# 701  newly_recorded_site/built_heritage -26.172528      27.992787
# 702  newly_recorded_site/built_heritage -26.172528      27.992787
# 703  newly_recorded_site/built_heritage -26.172528      27.992787
#
#      site altitude  site precision site extent  site geometry line  \
# 699  1702.900024    3.9             NaN        NaN
# 700  1702.900024    3.9             NaN        NaN
# 701  1702.900024    3.9             NaN        NaN
# 702  1702.900024    3.9             NaN        NaN
# 703  1702.900024    3.9             NaN        NaN
#
# ...

# %% [markdown]
# ## Removing the duplicates

# %%
# Remove duplicates:https://stackoverflow.com/questions/56044159/replace-duplicate-set-of-values-with-nan
# duplicated = main_merge_new.duplicated('index')
# main_merge_new.loc[duplicated, col_name_new] = np.NaN
main_merge_new_d = main_merge_new.drop_duplicates()
main_merge_new.shape  # previous shape
main_merge_new_d.shape  # new shape after removing duplicates
# Out:
# (10, 15)

# %%
main_merge_new_d.tail(8)
# Out:
#     associated id name associated id value  \
# 576  Sdff               Ssf1233
# 580  Sdff               Ssf1233
# 584  Sdff               Ssf1233
# 588  Sdff               Ssf1233
# 592  Sdff               Ssf1233
# 596  Sdff               Ssf1233
# 600  Sdff               Ssf1233
# 604  Sdff               Ssf1233
#
#                             site source  site latitude  site longitude  \
# 576  newly_recorded_site/built_heritage -26.172528      27.992787
# 580  newly_recorded_site/built_heritage -26.172528      27.992787
# 584  newly_recorded_site/built_heritage -26.172528      27.992787
# 588  newly_recorded_site/built_heritage -26.172528      27.992787
# 592  newly_recorded_site/built_heritage -26.172528      27.992787
# 596  newly_recorded_site/built_heritage -26.172528      27.992787
# 600  newly_recorded_site/built_heritage -26.172528      27.992787
# 604  newly_recorded_site/built_heritage -26.172528      27.992787
#
# ...

# %% [markdown]
# ## Replacing values in the main merge table with the correct ones

# %%
df_form.head(5)
# Out:
#            list_name                 name  label::English (en)  \
# 0  name_type          official             Official
# 1  name_type          primaire             Primaire
# 2  name_type          alternative          Alternative
# 3  site_type_summary  archaeological_site  Archaeological site
# 4  site_type_summary  settlement           Settlement
#
#   label::Français (fr) institution_name media::image transect_method_list
# 0  Official             NaN              NaN          NaN
# 1  Primaire             NaN              NaN          NaN
# 2  Alternative          NaN              NaN          NaN
# 3  Site archéologique   NaN              NaN          NaN
# 4  Établissement        NaN              NaN          NaN

# %%
df_form.columns.values
# Out:
# array(['list_name', 'name', 'label::English (en)', 'label::Français (fr)',
#        'institution_name', 'media::image', 'transect_method_list'],
#       dtype=object)

# %%
df_form_sub = df_form[['name', 'label::English (en)']] #subsetting to two columns (name, label) then rename
df_form_sub.rename(columns= {'label::English (en)': 'label'}, inplace=True)
# Out:
# C:\Users\zolok\miniconda3\envs\analysis\lib\site-packages\pandas\core\frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
## # create concept dict
concept_dict = pd.Series(df_form_sub.label.values,index=df_form_sub.name).to_dict()

# %%
# replace values using dict
df_final = main_merge_new_d.applymap(concept_dict.get).fillna(main_merge_new_d) #https://stackoverflow.com/questions/43725799/map-multiple-columns-by-a-single-dictionary-in-pandas

# %%
df_final.tail(3)
# Out:
#     associated id name associated id value  \
# 596  Sdff               Ssf1233
# 600  Sdff               Ssf1233
# 604  Sdff               Ssf1233
#
#                               site source site latitude site longitude  \
# 596  Newly Recorded Site / Built Heritage -26.172528     27.992787
# 600  Newly Recorded Site / Built Heritage -26.172528     27.992787
# 604  Newly Recorded Site / Built Heritage -26.172528     27.992787
#
#     site altitude site precision site extent site geometry line  \
# 596  1702.900024   3.9            NaN         NaN
# 600  1702.900024   3.9            NaN         NaN
# 604  1702.900024   3.9            NaN         NaN
#
#     site geometry polygon nearest village associated materials features  \
# 596  NaN                   Dyg             traces_burning
# 600  NaN                   Dyg             traces_burials
# 604  NaN                   Dyg             Walling_platefom
#
#     surface material type                         chronology index
# ...

# %% [markdown]
# ## Creating cards (for arches)

# %%
# Cards witll be based on index, associated materials features, surface material type, chronology (The columns will naturally have duplicates)
